# %%
# Instalar las bibliotecas necesarias (descomentar si no están instaladas)
# !pip install -q mplcursors
# !pip install -q seaborn

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import mplcursors
import seaborn as sns

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Definir colores peruanos
color_rojo = '#D91023'  # Rojo peruano
color_blanco = '#FFFFFF'  # Blanco
color_oscuro = '#333333'  # Para textos
color_acento = '#FFD700'  # Oro para acentos

# Generar datos ficticios de una serie temporal
fecha = pd.date_range(start="2020-01-01", periods=100, freq="M")
valores = np.sin(np.linspace(0, 10, 100)) + np.random.normal(0, 0.1, 100)  # Serie temporal con ruido

# Crear el DataFrame
datos_series_temporales = pd.DataFrame({'Fecha': fecha, 'Valor': valores})
datos_series_temporales.set_index('Fecha', inplace=True)

# Calcular una media móvil para la tendencia
datos_series_temporales['Media_Movil'] = datos_series_temporales['Valor'].rolling(window=12).mean()

# Graficar la serie temporal
plt.figure(figsize=(14, 7))
plt.plot(datos_series_temporales.index, datos_series_temporales['Valor'], label='Serie Temporal', color=color_rojo, alpha=0.7)
plt.plot(datos_series_temporales.index, datos_series_temporales['Media_Movil'], label='Media Móvil (12 meses)', color=color_acento, linewidth=2)

plt.title("📈 Análisis de Series Temporales - ¡Vamos por ese 19 de promedio! 🚀", fontsize=22, weight='bold', color=color_oscuro)
plt.xlabel('Fecha', fontsize=16, color=color_oscuro)
plt.ylabel('Valor', fontsize=16, color=color_oscuro)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatear las fechas en el eje X
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(10))
plt.gcf().autofmt_xdate()

# Mejorar la presentación
plt.tight_layout()

# Añadir interactividad
cursor = mplcursors.cursor(hover=True)
cursor.connect("add", lambda sel: sel.annotation.set_text(
    f"Fecha: {sel.target[0].strftime('%Y-%m')}\nValor: {sel.target[1]:.2f}"
))

plt.show()

# Mensaje HTML grande y llamativo con colores peruanos y estilo mejorado
mensaje = """
<div style='max-width: 900px; margin: auto; padding: 20px; text-align: center; font-family: Arial, sans-serif; background-color: #F5F5F5; border-radius: 10px;'>
    <h1 style='font-size: 60px; font-weight: bold; color: #D91023;'>
        ¡Ingeniero  ELOY, necesito un 19 de promedio! 🚀
    </h1>
    <p style='font-size: 24px; color: #333333; margin: 20px 0;'>
        Me dirijo a usted respetuosamente para solicitar una revisión de mi calificación final en el curso de <strong>Series Temporales</strong>, con el objetivo de alcanzar una calificación de <strong>19</strong>.
    </p>
    <div style='display: flex; justify-content: center; gap: 30px; flex-wrap: wrap;'>
        <div style='background-color: #FFFFFF; padding: 20px; border-radius: 8px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1); width: 250px;'>
            <h2 style='color: #D91023;'>📚 Aprende</h2>
            <p style='font-size: 18px; color: #555555;'>Domina las técnicas de análisis y predicción de datos temporales.</p>
        </div>
        <div style='background-color: #FFFFFF; padding: 20px; border-radius: 8px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1); width: 250px;'>
            <h2 style='color: #D91023;'>💻 Aplica</h2>
            <p style='font-size: 18px; color: #555555;'>Implementa modelos avanzados en proyectos reales.</p>
        </div>
        <div style='background-color: #FFFFFF; padding: 20px; border-radius: 8px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1); width: 250px;'>
            <h2 style='color: #D91023;'>🌟 Destaca</h2>
            <p style='font-size: 18px; color: #555555;'>Mejora tu promedio y abre puertas a nuevas oportunidades.</p>
        </div>
    </div>
    <p style='font-size: 20px; color: #D91023; margin-top: 30px;'>
        A continuación, presento un análisis detallado que refleja mi dedicación y comprensión de los conceptos aprendidos:
    </p>
    <div style='text-align: left; margin: 20px auto; max-width: 800px; background-color: #FFFFFF; padding: 20px; border-radius: 8px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);'>
        <h2 style='color: #D91023;'>📊 Proyecto Destacado: Análisis de Series Temporales</h2>
        <pre style='background-color: #F0F0F0; padding: 10px; border-radius: 5px; overflow-x: auto;'>
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import mplcursors
import seaborn as sns

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Definir colores peruanos
color_rojo = '#D91023'  # Rojo peruano
color_blanco = '#FFFFFF'  # Blanco
color_oscuro = '#333333'  # Para textos
color_acento = '#FFD700'  # Oro para acentos

# Generar datos ficticios de una serie temporal
fecha = pd.date_range(start="2020-01-01", periods=100, freq="M")
valores = np.sin(np.linspace(0, 10, 100)) + np.random.normal(0, 0.1, 100)  # Serie temporal con ruido

# Crear el DataFrame
datos_series_temporales = pd.DataFrame({'Fecha': fecha, 'Valor': valores})
datos_series_temporales.set_index('Fecha', inplace=True)

# Calcular una media móvil para la tendencia
datos_series_temporales['Media_Movil'] = datos_series_temporales['Valor'].rolling(window=12).mean()

# Graficar la serie temporal
plt.figure(figsize=(14, 7))
plt.plot(datos_series_temporales.index, datos_series_temporales['Valor'], label='Serie Temporal', color=color_rojo, alpha=0.7)
plt.plot(datos_series_temporales.index, datos_series_temporales['Media_Movil'], label='Media Móvil (12 meses)', color=color_acento, linewidth=2)

plt.title("📈 Análisis de Series Temporales - ¡Vamos por ese 19 de promedio! 🚀", fontsize=22, weight='bold', color=color_oscuro)
plt.xlabel('Fecha', fontsize=16, color=color_oscuro)
plt.ylabel('Valor', fontsize=16, color=color_oscuro)
plt.legend(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Formatear las fechas en el eje X
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(10))
plt.gcf().autofmt_xdate()

# Mejorar la presentación
plt.tight_layout()

# Añadir interactividad
cursor = mplcursors.cursor(hover=True)
cursor.connect("add", lambda sel: sel.annotation.set_text(
    f"Fecha: {sel.target[0].strftime('%Y-%m')}\nValor: {sel.target[1]:.2f}"
))

plt.show()
        </pre>
        <p style='font-size: 16px; color: #555555;'>
            Este proyecto refleja mi capacidad para manejar datos, aplicar técnicas estadísticas y presentar resultados de manera clara y efectiva. La visualización interactiva permite explorar los datos en detalle, identificando tendencias y patrones significativos.
        </p>
    </div>
    <p style='font-size: 20px; color: #333333; margin-top: 30px;'>
        Estoy completamente dispuesto/a a discutir cualquier aspecto de mi desempeño que considere necesario y a proporcionar documentación adicional que respalde esta solicitud. Aprecio profundamente su atención a esta petición y agradecería la oportunidad de conversar al respecto en el momento que usted considere oportuno.
    </p>
    <p style='font-size: 20px; color: #D91023; margin-top: 30px;'>
        ¡Analizando datos y entendiendo patrones, tu futuro es brillante! 💡
    </p>
    <p style='font-size: 20px; color: #333333; margin-top: 40px;'>
        <strong>Atentamente,</strong><br>
        VILCA SOLORZANO RICHAR ANDRE<br>


    </p>
</div>
"""

# Mostrar el mensaje
display(HTML(mensaje))
# Out:
# <ipython-input-8-c99c8fbe662c>:22: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   fecha = pd.date_range(start="2020-01-01", periods=100, freq="M")
# <ipython-input-8-c99c8fbe662c>:48: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   plt.tight_layout()
# <ipython-input-8-c99c8fbe662c>:48: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
